# %%
# Import the library.
import nltk

# Install the required tokenisation model.
nltk.download('punkt')

# Install the required tokenisation function.
from nltk.tokenize import sent_tokenize
# Out:
# [nltk_data] Downloading package punkt to /Users/adeola/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ### 2. Tokenise the sentences

# %%
# Assign the raw text data to a variable.
text = """We took this ball to the beach and after close to 2 hours to pump it up, 
we pushed it around for about 10 fun filled minutes. That was when the wind picked 
it up and sent it huddling down the beach at about 40 knots. It destroyed everything
in its path. Children screamed in terror at the giant inflatable monster that crushed 
their sand castles. Grown men were knocked down trying to save their families. 
The faster we chased it, the faster it rolled. It was like it was mocking us. 
Eventually, we had to stop running after it because its path of injury and destruction
was going to cost us a fortune in legal fees. Rumor has it that it can still be seen stalking
innocent families on the Florida panhandle. We lost it in South Carolina, so there is something
to be said about its durability."""

# Tokenise the text data.
tokenised_sentence = sent_tokenize(text)

# Check the result.
print(tokenised_sentence)
# Out:
# ['We took this ball to the beach and after close to 2 hours to pump it up, \nwe pushed it around for about 10 fun filled minutes.', 'That was when the wind picked \nit up and sent it huddling down the beach at about 40 knots.', 'It destroyed everything\nin its path.', 'Children screamed in terror at the giant inflatable monster that crushed \ntheir sand castles.', 'Grown men were knocked down trying to save their families.', 'The faster we chased it, the faster it rolled.', 'It was like it was mocking us.', 'Eventually, we had to stop running after it because its path of injury and destruction\nwas going to cost us a fortune in legal fees.', 'Rumor has it that it can still be seen stalking\ninnocent families on the Florida panhandle.', 'We lost it in South Carolina, so there is something\nto be said about its durability.']

# %% [markdown]
# ### 3. Tokenise the words

# %%
# Import the function.
from nltk.tokenize import word_tokenize

# Tokenise the text data.
tokenised_word = word_tokenize(text)

# Check the result.
print(tokenised_word)
# Out:
# ['We', 'took', 'this', 'ball', 'to', 'the', 'beach', 'and', 'after', 'close', 'to', '2', 'hours', 'to', 'pump', 'it', 'up', ',', 'we', 'pushed', 'it', 'around', 'for', 'about', '10', 'fun', 'filled', 'minutes', '.', 'That', 'was', 'when', 'the', 'wind', 'picked', 'it', 'up', 'and', 'sent', 'it', 'huddling', 'down', 'the', 'beach', 'at', 'about', '40', 'knots', '.', 'It', 'destroyed', 'everything', 'in', 'its', 'path', '.', 'Children', 'screamed', 'in', 'terror', 'at', 'the', 'giant', 'inflatable', 'monster', 'that', 'crushed', 'their', 'sand', 'castles', '.', 'Grown', 'men', 'were', 'knocked', 'down', 'trying', 'to', 'save', 'their', 'families', '.', 'The', 'faster', 'we', 'chased', 'it', ',', 'the', 'faster', 'it', 'rolled', '.', 'It', 'was', 'like', 'it', 'was', 'mocking', 'us', '.', 'Eventually', ',', 'we', 'had', 'to', 'stop', 'running', 'after', 'it', 'because', 'its', 'path', 'of', 'injury', 'and', 'destruction', 'was', 'going', 'to', 'cost', 'us', 'a', 'fortune', 'in', 'legal', 'fees', '.', 'Rumor', 'has', 'it', 'that', 'it', 'can', 'still', 'be', 'seen', 'stalking', 'innocent', 'families', 'on', 'the', 'Florida', 'panhandle', '.', 'We', 'lost', 'it', 'in', 'South', 'Carolina', ',', 'so', 'there', 'is', 'something', 'to', 'be', 'said', 'about', 'its', 'durability', '.']

# %% [markdown]
# ### 4. Analyse individual words

# %%
# Import the class.
from nltk.probability import FreqDist

# Create a frequency distribution object.
freq_dist_of_words = FreqDist(tokenised_word)

# Show the five most common elements in the data set.
freq_dist_of_words.most_common(5)
# Out:
# [('it', 11), ('.', 10), ('to', 7), ('the', 6), (',', 4)]

# %% [markdown]
# ### 5. Visualise the words

# %%
# Import the package.
import matplotlib.pyplot as plt

# Define the figure and axes.
fig, ax = plt.subplots(dpi=100)
fig.set_size_inches(12, 12)

# Plot the data set.
freq_dist_of_words.plot(30, cumulative=False)

# Display the result.
plt.show()

# %% [markdown]
# ## Normalisation

# %% [markdown]
# ### 6. Identify stopwords

# %%
# Download the stopwords.
nltk.download('stopwords')

# Import the package.
from nltk.corpus import stopwords

# Create a set of English stopwords.
stop_words = set(stopwords.words('english'))

# Display the set.
print(stop_words)
# Out:
# {'so', 'didn', 'with', 'needn', 'both', 'there', 'each', 're', 'aren', 'when', 'ourselves', 'himself', 'if', "aren't", 'during', 'we', 'more', "couldn't", 'hasn', 'at', 'mightn', 'now', 'can', 'very', 'their', 'doing', 'wasn', 'under', "shouldn't", 'am', 'themselves', 'than', "isn't", "don't", 'of', 'above', 'that', "hadn't", 'shouldn', 'why', 'where', 'don', 'myself', "wouldn't", 'he', 'against', 't', 'by', 'having', 'me', 'until', 'd', 'then', 'how', 'll', "you've", 'be', 'an', 'will', "haven't", 'herself', 'on', 'theirs', "it's", 'other', 'should', "that'll", "wasn't", "you'll", 'his', 'have', 'too', 'm', 've', 'weren', 'were', 'you', "won't", 'a', 'or', 'which', 'was', 'them', 'what', 'mustn', "you'd", 'below', 'who', 'some', 'our', "doesn't", 'my', 'doesn', 'do', 'y', "shan't", 'not', 'as', 'in', 'hers', 'did', 'shan', 'up', 'most', 'i', 'nor', 'ain', 'o', 'after', 'off', 'further', 'to', 'this', 'once', "mustn't", 'such', 'because', 'those', "needn't", 'its', 'ma', "should've", 'while', 'but', 'these', 'been', 'is', 'are', 'has', 'from', 's', 'him', 'into', 'just', 'yourselves', 'had', 'haven', 'any', "weren't", "mightn't", 'the', 'same', 'only', "hasn't", 'all', 'and', 'her', 'no', 'isn', 'wouldn', 'out', 'won', 'does', 'she', 'for', 'hadn', 'again', 'here', 'yours', "didn't", 'itself', 'it', "she's", 'being', 'few', 'through', "you're", 'yourself', 'before', 'ours', 'couldn', 'down', 'over', 'your', 'own', 'between', 'about', 'they', 'whom'}
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/adeola/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# ### 7. Remove the stopwords

# %%
# Create an empty list for the filtered words.
filtered_text = []

# Tokenise the text data.
# Create a tokenised word list.
tokenised_word = nltk.word_tokenize(text)

# Filter the tokenised words.
for each_word in tokenised_word:
    if each_word not in stop_words:
        filtered_text.append(each_word)
        
# Display the filtered list.      
print("Tokenised list without stopwords: {}".format(filtered_text))
# Out:
# Tokenised list without stopwords: ['We', 'took', 'ball', 'beach', 'close', '2', 'hours', 'pump', ',', 'pushed', 'around', '10', 'fun', 'filled', 'minutes', '.', 'That', 'wind', 'picked', 'sent', 'huddling', 'beach', '40', 'knots', '.', 'It', 'destroyed', 'everything', 'path', '.', 'Children', 'screamed', 'terror', 'giant', 'inflatable', 'monster', 'crushed', 'sand', 'castles', '.', 'Grown', 'men', 'knocked', 'trying', 'save', 'families', '.', 'The', 'faster', 'chased', ',', 'faster', 'rolled', '.', 'It', 'like', 'mocking', 'us', '.', 'Eventually', ',', 'stop', 'running', 'path', 'injury', 'destruction', 'going', 'cost', 'us', 'fortune', 'legal', 'fees', '.', 'Rumor', 'still', 'seen', 'stalking', 'innocent', 'families', 'Florida', 'panhandle', '.', 'We', 'lost', 'South', 'Carolina', ',', 'something', 'said', 'durability', '.']

# %% [markdown]
# ### 8. Stemming the data

# %%
# Import the necessary class.
from nltk.stem.snowball import SnowballStemmer

# Download the resource.
nltk.download('wordnet')

# Create a stemming object.
snow_stem = SnowballStemmer(language='english')

# Create a list of test words.
words = ['easily', 'durability', 'longest', 'wishing', 'worthwhile',
         'fantasizing', 'off-putting']

# Apply the stemming process to each word.
for word in words:
    print(word + "--->" + snow_stem.stem(word))
# Out:
# [nltk_data] Downloading package wordnet to /Users/adeola/nltk_data...
# easily--->easili
# durability--->durabl
# longest--->longest
# wishing--->wish
# worthwhile--->worthwhil
# fantasizing--->fantas
# off-putting--->off-put

# %% [markdown]
# ### 9. Lemmatise the data

# %%
# Import the necessary class.
from nltk.stem.wordnet import WordNetLemmatizer

# Download the lemma corpus.
nltk.download('omw-1.4')

# Create an instance of the class.
lemmatiser = WordNetLemmatizer()

# Create an empty output list.
lemmatised_words_list = []

# Define a text string to test.
text_2 = "I love it when he purchases items that the kids and grandkids can't wait to try out. it's a lot of fun but he easily and accidentally bowls the toddlers over with them, so be careful."

# Tokenise the string.
tokenised_word = word_tokenize(text_2)

# Apply lemmatisation to each tokenised word.
for each_word in tokenised_word:
    lem_word = lemmatiser.lemmatize(each_word)
    lemmatised_words_list.append(lem_word)

# Display the output list.
print("Lemmatised Words list {}".format(lemmatised_words_list))
# Out:
# [nltk_data] Downloading package omw-1.4 to /Users/adeola/nltk_data...
# Lemmatised Words list ['I', 'love', 'it', 'when', 'he', 'purchase', 'item', 'that', 'the', 'kid', 'and', 'grandkids', 'ca', "n't", 'wait', 'to', 'try', 'out', '.', 'it', "'s", 'a', 'lot', 'of', 'fun', 'but', 'he', 'easily', 'and', 'accidentally', 'bowl', 'the', 'toddler', 'over', 'with', 'them', ',', 'so', 'be', 'careful', '.']

# %% [markdown]
# ### 10. Remove punctuation

# %%
# Import the necessary module.
import re

# Define some text. 
text_3 = "Perfect! Buying a second. Using it to make a hot air balloon for an escape room adventure. Event in Oct. will share photos."

# Filter out the specified punctuation.
no_punct = re.sub(r"[\.\?\!\,\:\;\"]", '', text_3)

# Display the filtered text.
print(no_punct)
# Out:
# Perfect Buying a second Using it to make a hot air balloon for an escape room adventure Event in Oct will share photos
